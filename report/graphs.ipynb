# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
implementations = ['Python+NumPy', 'C++', 'Shader (Batch=1)', 'Shader (Batch=2400)']
x = np.arange(len(implementations))
times_10k = [0.91,2.18,0.37, 0.028]
times_60k = [5.51,13.3,2.36,0.15]
colors = ['#1f77b4', 'orange', '#76B900', '#76B900']
width = 0.35

# Create a bar chart
plt.figure(figsize=(8, 6))
bars1 = plt.bar(x - width/2, times_10k, width, label='10k Images', color=colors)
bars2 = plt.bar(x + width/2, times_60k, width, label='60k Images', color=colors)

# Add labels and title
plt.xlabel('Implementation')
plt.ylabel('Execution Time (seconds)')
plt.xticks(x, implementations)
plt.title('Forward Propagation Execution Time Comparison')

# Add text labels on top of each bar
for bar, label in zip(bars1, ['10k'] * len(bars1)):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom')
for bar, label in zip(bars2, ['60k'] * len(bars2)):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom')

# Save the plot to a file
plt.savefig('images/forward_prop_time_comparison.png')

# Display the plot
plt.show()

# %%
implementations = ['PyTorch', 'Shader', 'Tensor', 'cuBLAS']
x = np.arange(len(implementations))
times_10k = [0, 0.028, .0022, .0024]
times_60k = [0.062, 0.15, .0095, .0076]
colors = ['#1f77b4', '#76B900', '#76B900', '#76B900']
width = 0.35

# Create a bar chart
plt.figure(figsize=(8, 6))
bars1 = plt.bar(x - width/2, times_10k, width, label='10k Images', color=colors)
bars2 = plt.bar(x + width/2, times_60k, width, label='60k Images', color=colors)

# Add labels and title
plt.xlabel('Implementation')
plt.ylabel('Execution Time (seconds)')
plt.xticks(x, implementations)
plt.title('Forward Propagation Execution Time Comparison')

# Add text labels on top of each bar
for bar, label in zip(bars1, ['']+['10k']* (len(bars2)-1)):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom')
for bar, label in zip(bars2, ['60k'] * len(bars2)):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom')

# Save the plot to a file
plt.savefig('images/forward_prop_time_comparison2.png')

# Display the plot
plt.show()

# %%
implementations = ['Python+NumPy', 'C++', 'CUDA']
x = np.arange(len(implementations))
times_10k = [13.9,7.00,4.08]
times_60k = [82,41.9,24.6]
colors = ['#1f77b4', 'orange', '#76B900']
width = 0.35

# Create a bar chart
plt.figure(figsize=(8, 6))
bars1 = plt.bar(x - width/2, times_10k, width, label='10k Images', color=colors)
bars2 = plt.bar(x + width/2, times_60k, width, label='60k Images', color=colors)

# Add labels and title
plt.xlabel('Implementation')
plt.ylabel('Execution Time (seconds)')
plt.xticks(x, implementations)
plt.title('Backwards Propagation Execution Time Comparison')

# Add text labels on top of each bar
for bar, label in zip(bars1, ['10k'] * len(bars1)):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom')
for bar, label in zip(bars2, ['60k'] * len(bars2)):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), label, ha='center', va='bottom')

# Save the plot to a file
plt.savefig('images/backward_prop_time_comparison.png')

# Display the plot
plt.show()

# %%
# Data
batch_sizes = [1, 2, 15, 30, 60, 120, 2400, 24000, 60000]
times_60k = [2.36, 1.18, 0.227, 0.19, 0.168, 0.157, 0.13, 0.158, 0.139]

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(batch_sizes, times_60k, marker='o')

# Set labels, title, and x-axis scale
plt.xlabel('Batch Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Forward Propagation Batch Size Comparison')
plt.xscale('log')
plt.xticks(batch_sizes)

# Formatter for exact batch size values on x-axis
plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

# Save the plot to a file
plt.savefig('images/forward_batch_time_comparison.png')

# Display the plot
plt.show()

# %%
# Data
threaad_block_sizes = [8, 16, 32, 64, 128, 256, 512]
times_60k_2400 = [0.160, 0.142, 0.134, 0.143, 0.151, 0.155, 0.157]
times_60k_15 = [0.256, 0.234, 0.236, 0.256, 0.252, 0.419, 0.472]
times_60k_6 = [0.393, 0.437,  0.477, 0.480, 0.603, 1.025, 1.15]

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(threaad_block_sizes, times_60k_2400, marker='o', label='2400')
plt.plot(threaad_block_sizes, times_60k_15, marker='o', label='15')
plt.plot(threaad_block_sizes, times_60k_6, marker='o', label='6')

# Set labels, title, and x-axis scale
plt.xlabel('Thread Block Size')
plt.ylabel('Execution Time (seconds)')
plt.title('Forward Propagation Thread Block Size Comparison')
plt.xscale('log')
plt.xticks(threaad_block_sizes)
plt.legend(title='Batch Size')

# Formatter for exact batch size values on x-axis
plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x):,}'))

# Save the plot to a file
plt.savefig('images/forward_block_size_time_comparison.png')

# Display the plot
plt.show()
